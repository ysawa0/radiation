# %%
import dicom
import os
import sys
import glob
import numpy as np
from collections import Counter,OrderedDict
import matplotlib.pyplot as plt
sys.path.append("..")
from AlgoEngine.utils import getImageBlock

# %% [markdown]
# ## Inputs to Function

# %%
StudyID = 'UCLA_PR_5'

# %% [markdown]
# ## Function

# %%
imageBlock, sopUID = getImageBlock(StudyID)

# %% [markdown]
# ## Testing Function
#
# We display 10 CT images to confirm that the CT images are
#
# *In Head to Leg order
#
# *Of the proper resolution (512 x 512) and can be displayed as CT scans in grayscale

# %%
for index in range(0, 300, 10):
        plt.figure(index)
        plt.imshow(imageBlock[:,:,index],cmap=plt.get_cmap('gray'))
        plt.show()
